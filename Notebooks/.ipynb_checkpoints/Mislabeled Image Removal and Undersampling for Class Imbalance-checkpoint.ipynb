# %%
import numpy as np
import pandas as pd

#img show and plotting
import matplotlib.pyplot as plt
import seaborn as sns
# from matplotlib import image

#image functions
from ImageFunctions import get_color_description, plot_color_hist, show_image, load_image, show_save_image
from ImageFunctions import show_images, get_categories_top_bottom_imgs, get_sorted_distances_list, remove_bottom_imgs

# # color distributions
# import cv2
# import imutils

# class imbalance
import random

# splitting
from sklearn.model_selection import train_test_split

# #img load
# import requests
# # !pip install fake_useragent
# from fake_useragent import UserAgent 
# from io import BytesIO
# from PIL import Image

# img augmentation
from skimage import exposure, transform
from skimage.util import random_noise
# from cv2 import resize
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-f5f9a27a8889> in <module>
#       8
#       9 #image functions
# ---> 10 from ImageFunctions import get_color_description, plot_color_hist, show_image, load_image, show_save_image
#      11 from ImageFunctions import show_images, get_categories_top_bottom_imgs, get_sorted_distances_list, remove_bottom_imgs
#      12
#
# ImportError: cannot import name 'get_color_description' from 'ImageFunctions' (/Users/racheldilley/Documents/Metis/git_repos/lets_take_a_trip/Notebooks/ImageFunctions.py)

# %%
# def histogram(image, mask, bins ):
#     # extract a 3D color histogram from the masked region of the image, using the supplied number of bins per channel
#     hist = cv2.calcHist([image], [0,1,2], mask, bins, [0, 256, 0, 256, 0, 256])
    
#     # normalize the histogram if we are using OpenCV 2.4
#     if imutils.is_cv2():
#         hist = cv2.normalize(hist).flatten()
        
#     # otherwise handle for OpenCV 3+
#     else:
#         hist = cv2.normalize(hist, hist).flatten()

#     return hist

# def plot_color_hist(image, bins, mask, name):

#     rgb    = cv2.split(image)

#     plt.figure(figsize = (10,5))
#     colors = ['r','g','b']
    
#     for i,col in enumerate(colors):
#         arr = rgb[i] * mask
#         arr = arr.flatten()
#         plt.hist(list(arr), bins, [1,256], color=col) 

#         plt.xlim([0,256])
        
#     #save
#     if name != None:
#         path = '../Graphs/' + 'color_hist_bottom_right' + '.png'
#         plt.savefig(path)
    
#     plt.show()

# def show_image(img):
    
#     imgplot = plt.imshow(img)
#     plt.axis('off')
#     plt.grid(False)
#     plt.show()
    
# def load_image(url):
#     ua = UserAgent()
#     headers = {'user-agent': ua.random}

#     response = requests.get(url, headers = headers)
#     image_io = BytesIO(response.content)
#     img = Image.open(image_io)    
#     return np.array(img)

    
# def show_save_image(img, name):
#     # show
#     plt.rcParams['figure.figsize']=(4,4)
#     imgplot = plt.imshow(img)
#     plt.axis('off')
#     plt.grid(False)
#     plt.show()
    
    #save
#     path = '../Graphs/' + name + '.png'
#     image.imsave(path, img)
    
# def show_images(img_list, category):
#     plt.figure(figsize = (25,15));
#     t = f"Showing from {category} category"
    
#     plt.suptitle(t, fontsize=20)
#     for index, img in enumerate(img_list):
#         plt.subplot(10,10,index+1);
#         plt.imshow(img)
#         plt.axis('off')
    
# def get_color_description(img_array, bins, color):
#     img = img_array * 255
#     image = cv2.cvtColor(img, color)
    
#     features = []
   
#     # grab the dimensions and compute the center of the image
#     (h, w) = image.shape[:2]
#     (cX, cY) = (int(w * 0.5), int(h * 0.5))

#     # divide the image into four rectangles/segments (top-left, top-right, bottom-right, bottom-left)
#     segments = [(0, cX, 0, cY), (cX, w, 0, cY), (cX, w, cY, h), (0, cX, cY, h)]

#     # construct an elliptical mask representing the center of the image
#     (axesX, axesY) = (int(w * 0.75) // 2, int(h * 0.75) // 2)
#     ellipMask = np.zeros(image.shape[:2], dtype = "uint8")
#     cv2.ellipse(ellipMask, (cX, cY), (axesX, axesY), 0, 0, 360, 255, -1)

#     # loop over the segments
#     for (startX, endX, startY, endY) in segments:
#         # construct a mask for each corner of the image, subtracting the elliptical center from it
#         cornerMask = np.zeros(image.shape[:2], dtype = "uint8")
#         cv2.rectangle(cornerMask, (startX, startY), (endX, endY), 255, -1)
#         cornerMask = cv2.subtract(cornerMask, ellipMask)

#         # extract a color histogram from the image, then update the feature vector
#         hist = histogram(image, cornerMask,bins)
#         features.extend(hist)

#         # extract a color histogram from the elliptical region and update the feature vector
#         hist = histogram(image, ellipMask, bins)
#         features.extend(hist)
#     return features

# def get_categories_top_bottom_imgs(df, categories, num):
#     grouped = df.groupby('category')
#     group_centroid = df.groupby("category")["color_feats"].apply(lambda x: np.array(x.tolist()).mean(axis=0))

#     firstvals = {}
#     lastvals = {}

    
#     for idx,cat in enumerate(categories):
#         group = grouped.get_group(cat) 

#         cent = group_centroid[cat]

#         sorted_dist = get_sorted_distances_list(group, cent)
        
#         firstvals[cat] = [k for k in list(sorted_dist.keys())[:num]]
#         lastvals[cat] = [k for k in list(sorted_dist.keys())[-num:]]
    
#     return (firstvals, lastvals)

# def get_sorted_distances_list(df, feat):
#     distances = {}
#     for index, row in df.iterrows():
#         pt = np.array(row[4])
#         dist = np.linalg.norm(feat-pt)
#         distances[index] = dist

#     # distances
#     sorted_dist = dict(sorted(distances.items(), key=lambda item: item[1]))
    
#     return sorted_dist

# def remove_bottom_imgs(X, df, categories, bottom_imgs_dict, remove):
#     remove_indexes = remove
#     for cat in categories:
#         remove_indexes = remove_indexes + bottom_imgs_dict[cat]
        
#     df.drop(df.index[remove_indexes], inplace = True)
#     X = np.delete(X, remove_indexes, 0)
    
#     return X, df

# %% [markdown]
# ### Load Data

# %%
#data saved to local drive
X = np.load('/Users/racheldilley/Documents/lets-take-a-trip-data/X2.npy')
df = pd.read_pickle('/Users/racheldilley/Documents/lets-take-a-trip-data/Y2.pkl')

print(X.shape, df.shape) #check for same length
# Out:
# (74698, 150, 150, 3) (74698, 4)

# %%
df['category'].value_counts()
# Out:
# parks            22719
# landmarks        11030
# entertainment    10507
# museums           9441
# beaches/ocean     8498
# gardens/zoo       7468
# art               3121
# sports            1914
# Name: category, dtype: int64

# %% [markdown]
# Reset index of df to mastch index numbers of X

# %%
df.reset_index(inplace=True)
df.drop(['index'], 1, inplace=True)
df.tail(2)
# Out:
#                            name                          location   category  \
# 74696  Antler Arches of Jackson  US Highway 26, Jackson, WY 83001  landmarks
# 74697  Antler Arches of Jackson  US Highway 26, Jackson, WY 83001  landmarks
#
#                                                      url
# 74696  https://media-cdn.tripadvisor.com/media/photo-...
# 74697  https://media-cdn.tripadvisor.com/media/photo-...

# %% [markdown]
# ### Get list of color features for each image and add to df

# %% [markdown]
# - Split up image into center elipse and 4 corners of image
# - Find R,G, and B color distributions with specified number of bins for each image

# %%
bins = [8,8,8]
color = cv2.COLOR_BGR2HSV
#BGR2RGB

color_feats = []
for x in X:
    color_feats.append(get_color_description(x, bins, color))

np.array(color_feats).shape
# Out:
# (74698, 4096)

# %%
df['color_feats'] = color_feats
df.info()

del color_feats
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74698 entries, 0 to 74697
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         74698 non-null  object
#  1   location     74646 non-null  object
#  2   category     74698 non-null  object
#  3   url          74698 non-null  object
#  4   color_feats  74698 non-null  object
# dtypes: object(5)
# memory usage: 2.8+ MB

# %% [markdown]
# ##### Get examples of color distributions and graphs for presentation

# %%
idx = 3457
url = df.loc[idx, 'url']

img = load_image(url)

show_save_image(img, 'color_feats')

# grab the dimensions and compute the center of the image
(h, w) = img.shape[:2]
(cX, cY) = (int(w * 0.5), int(h * 0.5))

# divide the image into four rectangles/segments (top-left, top-right, bottom-right, bottom-left)
segments = [(0, cX, 0, cY), (cX, w, 0, cY), (cX, w, cY, h), (0, cX, cY, h)]

rect = []
# loop over the segments
for (startX, endX, startY, endY) in segments:
    # construct a mask for each corner of the image, subtracting the elliptical center from it
    cornerMask = np.zeros(img.shape[:2], dtype = "uint8")
    rect.append((cv2.rectangle(cornerMask, (startX, startY), (endX, endY), 1, -1))) #*img))
#     cornerMask = cv2.subtract(cornerMask, ellipMask)

bins = 12
mask = rect[2]
plot_color_hist(img, bins, mask, None)
# df = pd.DataFrame(img[0])
# list(df[2])

# %% [markdown]
# ## Find mislabeled images in each category and remove

# %% [markdown]
# ### Investigate color distributions

# %% [markdown]
# - Calculate the centroid of color distributions for each category
# - Find closest and furthest images from centriod to show and investigate
# - Remove furthest images and other specified indexes

# %%
categories = ['museums', 'parks','beaches/ocean', 'gardens/zoo', 'landmarks',  'art', 'entertainment', 'sports']

firstimgs, lastimgs = get_categories_top_bottom_imgs(df, categories, 10)

# for key,value in lastimgs.items():
#     show_images(X[value], key)

# %%
# for key,value in firstimgs.items():
#     show_images(X[value], key)

# %%
remove = []
X_cleaned, df_cleaned = remove_bottom_imgs(X, df, categories, lastimgs, remove)
print(X_cleaned.shape, df_cleaned.shape)

# clear up memory
del X
del df
# Out:
# (74618, 150, 150, 3) (74618, 5)

# %% [markdown]
# ## Handling Class Imbalance

# %%
plt.rcParams['figure.figsize']=(15,8)
sns.set(font_scale = 1.4)
sns.countplot(df_cleaned['category'], palette=['orange'])
plt.ylim((0,25000))

plt.savefig('../Graphs/imbalanced.png')
# Out:
# /Users/racheldilley/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Combine Sports and Entertainemnt and Art and Museums

# %%
df_cleaned_classes = df_cleaned.copy()
df_cleaned_classes = df_cleaned_classes.reset_index()
X_cleaned_classes = X_cleaned.copy()

df_cleaned_classes['category'] = df_cleaned_classes['category'].str.replace('sports','entertainment')
df_cleaned_classes['category'] = df_cleaned_classes['category'].str.replace('art','museums')

# save each category as pickle
new_cats = ['museums', 'parks','beaches/ocean', 'gardens/zoo', 'landmarks', 'entertainment']
new_cats_name = ['museums', 'parks','beaches_ocean', 'gardens_zoo', 'landmarks', 'entertainment']
grouped = df_cleaned_classes.groupby('category')
for idx, cat in enumerate(new_cats):
    path = '../Data/' + new_cats_name[idx] + '_df.pkl'
    local_path = '/Users/racheldilley/Documents/lets-take-a-trip-data/AppData/' + new_cats_name[idx] + '_df.pkl'
    grouped.get_group(cat).to_pickle(local_path)

#clear up memory
del df_cleaned
del X_cleaned

# sns.set(font_scale = 1.7)
# sns.countplot(df_cleaned_classes['category'], palette=['orange'])
# plt.ylim((0,25000))

# plt.savefig('../Graphs/class_removal.png')

# %% [markdown]
# ### Undersampling

# %%
grouped = df_cleaned_classes.groupby('category')
museum_len = len(grouped.get_group('museums'))
parks_len = len(grouped.get_group('parks'))
num_to_remove = parks_len - museum_len


parks_indexes = grouped.get_group('parks').index.tolist()
# for x in range(0, num_to_remove):
indexes_to_remove =  random.sample(parks_indexes, num_to_remove)
print(num_to_remove, len(indexes_to_remove))

df_cleaned_classes.drop(df_cleaned_classes.index[indexes_to_remove], inplace = True)
X_cleaned_classes = np.delete(X_cleaned_classes, indexes_to_remove, 0)
print(len(df_cleaned_classes), len(X_cleaned_classes))

del grouped
del indexes_to_remove
# Out:
# 10167 10167
# 64451 64451

# %%
sns.countplot(df_cleaned_classes['category'], palette=['orange'])
plt.ylim((0,25000))

plt.savefig('../Graphs/undersampling.png')
# Out:
# /Users/racheldilley/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Image Augmentation

# %% [markdown]
# ##### Image augmentation example for presentation

# %%
url = df_cleaned_classes.loc[6790, 'url']
#888
img = load_image(url)

show_save_image(img, 'regular')

horiz = np.fliplr(img)

show_save_image(horiz, 'flipped')

trans = transform.rotate(img, random.uniform(-30,30))

show_save_image(trans, 'transformed')

noise = random_noise(img, mode='s&p', clip=True)

show_save_image(noise, 'noise')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f752fb6f30ce> in <module>
#       9 show_save_image(horiz, 'flipped')
#      10
# ---> 11 trans = transform.rotate(img, random.uniform(-30,30))
#      12
#      13 show_save_image(trans, 'transformed')
#
# NameError: name 'transform' is not defined

# %%
# def get_augmented_imgs(X,y):
#     X_aug = []
#     y_aug = []

#     for idx,img in enumerate(X):
#         X_aug.append(np.fliplr(img))
#         y_aug.append(y[idx])

#         X_aug.append(transform.rotate(img, random.uniform(-30,30)))
#         y_aug.append(y[idx])

#         X_aug.append(random_noise(img, mode='s&p', clip=True))
#         y_aug.append(y[idx])
        
#     return (np.array(X_aug), np.array(y_aug))

# df_cleaned_classes = df_cleaned_classes.reset_index()
# X_augmented, y_augmented = get_augmented_imgs(X_cleaned_classes, df_cleaned_classes['category'])

# del df_cleaned_classes
# del X_cleaned_classes

# %% [markdown]
# ### Split data into train, test, and validation sets

# %%
y = df_cleaned_classes['category']
del df_cleaned_classes

# create training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_cleaned_classes, y, test_size=0.2)

del y
del X_cleaned_classes

# create training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25)

print(X_train.shape, X_val.shape, X_test.shape)
print(y_train.shape, y_val.shape, y_test.shape)

# %% [markdown]
# ### Pickle and save cleaned data locally

# %%
import pickle

# save cleaned X
np.save('/Users/racheldilley/Documents/lets-take-a-trip-data/X_train_clean.npy',X_train)
del X_train
np.save('/Users/racheldilley/Documents/lets-take-a-trip-data/X_test_clean.npy',X_test)
del X_test
np.save('/Users/racheldilley/Documents/lets-take-a-trip-data/X_val_clean.npy',X_val)
del X_val

# save cleaned Y
y_train.to_pickle('/Users/racheldilley/Documents/lets-take-a-trip-data/Y_train_clean.pkl')
y_test.to_pickle('/Users/racheldilley/Documents/lets-take-a-trip-data/Y_test_clean.pkl')
y_val.to_pickle('/Users/racheldilley/Documents/lets-take-a-trip-data/Y_val_clean.pkl')

# svaing for google cloud platform
pickle.dump(y_train, '/Users/racheldilley/Documents/lets-take-a-trip-data/Y_train_clean.pkl', protocol=2)
pickle.dump(y_test, '/Users/racheldilley/Documents/lets-take-a-trip-data/Y_test_clean.pkl', protocol=2)
pickle.dump(y_val, '/Users/racheldilley/Documents/lets-take-a-trip-data/Y_val_clean.pkl', protocol=2)
